# %% [markdown]
# # Механическая торговая система — прогон для отчёта
#
# Актив: Яндекс (YNDX). Индикаторы: EMA 20/60, VWAP. Таймфрейм: 1h.
#
# Запусти ячейки по порядку.

# %%
import sys
from pathlib import Path
PROJECT_ROOT = Path.cwd() if Path.cwd().name == 'TradingSystem' else Path('.').resolve()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

# 1. Загрузка данных
from data.download_data import main as download_main
download_main()

# %%
# 2. Метод 1 — изолированность входа/выхода
from backtest_isolated import main as method1_main
method1_main()

# %%
# 3. Метод 2 — визуально-графический анализ
from backtest_visual import main as method2_main
method2_main()

# %%
# 4. Файлы для отчёта
from pathlib import Path
d = Path('data')
for f in ['method1_isolated_results.csv', 'method2_visual_results.csv', 'method2_visual_plot.png', 'equity_curve_method1.png']:
    p = d / f
    print(f"Есть: {p}" if p.exists() else f"Нет: {p}")
